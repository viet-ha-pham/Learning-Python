# %%
# !pip install audiocraft
# Out:
# Collecting audiocraft
#   Downloading audiocraft-0.0.1.tar.gz (259 kB)
# Collecting av
#   Downloading av-10.0.0-cp39-cp39-win_amd64.whl (25.3 MB)
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
# Collecting flashy>=0.0.1
#   Downloading flashy-0.0.2.tar.gz (72 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting hydra_colorlog
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting julius
#   Downloading julius-0.2.7.tar.gz (59 kB)
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from audiocraft) (1.21.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-win_amd64.whl (977 kB)
# Collecting spacy==3.5.2
#   Downloading spacy-3.5.2-cp39-cp39-win_amd64.whl (12.2 MB)
# Collecting torch>=2.0.0
#   Downloading torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
# Collecting torchaudio>=2.0.0
#   Downloading torchaudio-2.0.2-cp39-cp39-win_amd64.whl (2.1 MB)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from audiocraft) (4.64.0)
# Requirement already satisfied: transformers in d:\anaconda3\lib\site-packages (from audiocraft) (4.28.1)
# Collecting xformers
#   Downloading xformers-0.0.20-cp39-cp39-win_amd64.whl (97.6 MB)
# Collecting demucs
#   Downloading demucs-4.0.0.tar.gz (1.2 MB)
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (21.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (8.1.10)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (1.10.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (1.0.4)
# Requirement already satisfied: pathy>=0.10.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (0.7.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (3.0.8)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (2.11.3)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (61.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (2.27.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda3\lib\site-packages (from spacy==3.5.2->audiocraft) (6.3.0)
# Collecting dora-search
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting omegaconf<2.4,>=2.2
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
# Requirement already satisfied: PyYAML>=5.1.0 in d:\anaconda3\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.1->audiocraft) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy==3.5.2->audiocraft) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.2->audiocraft) (4.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->audiocraft) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->audiocraft) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->audiocraft) (0.7.9)
# Requirement already satisfied: sympy in d:\anaconda3\lib\site-packages (from torch>=2.0.0->audiocraft) (1.10.1)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from torch>=2.0.0->audiocraft) (3.6.0)
# Requirement already satisfied: networkx in d:\anaconda3\lib\site-packages (from torch>=2.0.0->audiocraft) (2.7.1)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm->audiocraft) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.2->audiocraft) (8.0.4)
# Collecting diffq>=0.2.1
#   Downloading diffq-0.2.4-cp39-cp39-win_amd64.whl (93 kB)
# Collecting lameenc>=1.2
#   Downloading lameenc-1.4.2-cp39-cp39-win_amd64.whl (158 kB)
# Collecting openunmix
#   Downloading openunmix-1.2.1-py3-none-any.whl (46 kB)
# Requirement already satisfied: Cython in d:\anaconda3\lib\site-packages (from diffq>=0.2.1->demucs->audiocraft) (0.29.28)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting submitit
#   Downloading submitit-1.4.5-py3-none-any.whl (73 kB)
# Collecting treetable
#   Downloading treetable-0.2.5.tar.gz (10 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy==3.5.2->audiocraft) (2.0.1)
# Requirement already satisfied: numba>=0.51.0 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (0.55.1)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp39-cp39-win_amd64.whl (184 kB)
# Requirement already satisfied: msgpack>=1.0 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (1.0.2)
# Collecting pooch<1.7,>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: decorator>=4.3.0 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (4.4.2)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: scipy>=1.2.0 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (1.7.3)
# Requirement already satisfied: joblib>=0.14 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in d:\anaconda3\lib\site-packages (from librosa->audiocraft) (1.0.2)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->audiocraft) (0.38.0)
# Requirement already satisfied: appdirs>=1.3.0 in d:\anaconda3\lib\site-packages (from pooch<1.7,>=1.0->librosa->audiocraft) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa->audiocraft) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in d:\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa->audiocraft) (1.15.0)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->audiocraft) (2.21)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: six>=1.7.0 in d:\anaconda3\lib\site-packages (from retrying->dora-search->flashy>=0.0.1->audiocraft) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in d:\anaconda3\lib\site-packages (from submitit->dora-search->flashy>=0.0.1->audiocraft) (2.0.0)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda3\lib\site-packages (from sympy->torch>=2.0.0->audiocraft) (1.2.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in d:\anaconda3\lib\site-packages (from transformers->audiocraft) (0.13.4)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda3\lib\site-packages (from transformers->audiocraft) (2022.3.15)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in d:\anaconda3\lib\site-packages (from transformers->audiocraft) (0.13.3)
# Collecting pyre-extensions==0.0.29
#   Downloading pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Collecting typing-inspect
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\anaconda3\lib\site-packages (from typing-inspect->pyre-extensions==0.0.29->xformers->audiocraft) (0.4.3)
# Building wheels for collected packages: audiocraft, flashy, antlr4-python3-runtime, demucs, julius, dora-search, audioread, docopt, treetable
#   Building wheel for audiocraft (setup.py): started
#   Building wheel for audiocraft (setup.py): finished with status 'done'
#   Created wheel for audiocraft: filename=audiocraft-0.0.1-py3-none-any.whl size=110232 sha256=dacf41a3256949978c12571a4eeef054b51ed9efff9ab77781a3acc7970ca473
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\a6\31\57\72228d6fa896166cfae24321af8bdac53be40a8e297ddfa861
#   Building wheel for flashy (PEP 517): started
#   Building wheel for flashy (PEP 517): finished with status 'done'
#   Created wheel for flashy: filename=flashy-0.0.2-py3-none-any.whl size=34569 sha256=584f556ee3fb3397035ae51fc0fa65f282beb073fe635499d89a197542ed36d0
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\d6\84\db\24e5a6c86d7ace28bb50d5d95b392ccb402cb0d2d9e546df9f
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144587 sha256=5dedb5aa9791c179fb19950e0c4d1e218591977261b0250e8272d6618b756e9e
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\23\cf\80\f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for demucs (setup.py): started
#   Building wheel for demucs (setup.py): finished with status 'done'
#   Created wheel for demucs: filename=demucs-4.0.0-py3-none-any.whl size=76523 sha256=38f6f82f9a8891db38fa2965d82224000f921a272104b79d8a11549a0d4141ab
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\aa\30\52\0a577b77ed9c0d30e7f6ea04aa1dae64213bab99dcf06ef476
#   Building wheel for julius (setup.py): started
#   Building wheel for julius (setup.py): finished with status 'done'
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21894 sha256=03f12621f605a97733b62a85825a6587288aa40da6023c92976b4f5ad7b7eb39
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\53\0a\a7\fc08f97438f4969d86afa7904336c2eb7eb422101359f3ad11
#   Building wheel for dora-search (PEP 517): started
#   Building wheel for dora-search (PEP 517): finished with status 'done'
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75223 sha256=997cef53894e3a2dd8bd634bd98fc461e0a78c22c9e3661f691525be4db8685b
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\a2\59\44\10cfedb7fe92293c00755c8c34a87691e0cbc7f6a553f57613
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=bbc2c3030df83acd5fc11ba97be814cccd614e0a8957f635138bc882f93a464c
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\e4\76\a4\cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9d8249a6d8e43ec4d730e5500fc4d1481326426a6665e50505ec37d6d55e2570
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\70\4a\46\1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
#   Building wheel for treetable (setup.py): started
#   Building wheel for treetable (setup.py): finished with status 'done'
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7349 sha256=8f50eebb9b4ddc24e9762f3e8f4f96762bce6c92d676422a456c4b0e406885f3
#   Stored in directory: c:\users\dell g7\appdata\local\pip\cache\wheels\eb\15\60\84d5b8d3b2c8d70583081c70f9628d9e300e44e537559bdb2d
# Successfully built audiocraft flashy antlr4-python3-runtime demucs julius dora-search audioread docopt treetable
# Installing collected packages: torch, antlr4-python3-runtime, typing-inspect, treetable, torchaudio, submitit, retrying, omegaconf, soxr, soundfile, pyre-extensions, pooch, openunmix, lazy-loader, lameenc, julius, hydra-core, einops, dora-search, docopt, diffq, colorlog, audioread, xformers, spacy, sentencepiece, num2words, librosa, hydra-colorlog, flashy, demucs, av, audiocraft
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1
#     Uninstalling torchaudio-0.12.1:
#       Successfully uninstalled torchaudio-0.12.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.3
#     Uninstalling spacy-3.5.3:
#       Successfully uninstalled spacy-3.5.3
# Successfully installed antlr4-python3-runtime-4.9.3 audiocraft-0.0.1 audioread-3.0.0 av-10.0.0 colorlog-6.7.0 demucs-4.0.0 diffq-0.2.4 docopt-0.6.2 dora-search-0.1.12 einops-0.6.1 flashy-0.0.2 hydra-colorlog-1.2.0 hydra-core-1.3.2 julius-0.2.7 lameenc-1.4.2 lazy-loader-0.2 librosa-0.10.0.post2 num2words-0.5.12 omegaconf-2.3.0 openunmix-1.2.1 pooch-1.6.0 pyre-extensions-0.0.29 retrying-1.3.4 sentencepiece-0.1.99 soundfile-0.12.1 soxr-0.3.5 spacy-3.5.2 submitit-1.4.5 torch-2.0.1 torchaudio-2.0.2 treetable-0.2.5 typing-inspect-0.9.0 xformers-0.0.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1 requires torch==1.12.1, but you have torch 2.0.1 which is incompatible.

# %%
# !pip install torchaudio
# Out:
# Requirement already satisfied: torchaudio in d:\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: torch==2.0.1 in d:\anaconda3\lib\site-packages (from torchaudio) (2.0.1)
# Requirement already satisfied: filelock in d:\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (3.6.0)
# Requirement already satisfied: networkx in d:\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (2.7.1)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (2.11.3)
# Requirement already satisfied: sympy in d:\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (1.10.1)
# Requirement already satisfied: typing-extensions in d:\anaconda3\lib\site-packages (from torch==2.0.1->torchaudio) (4.6.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->torch==2.0.1->torchaudio) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda3\lib\site-packages (from sympy->torch==2.0.1->torchaudio) (1.2.1)

# %%
import torchaudio
from audiocraft.models import MusicGen
from audiocraft.data.audio import audio_write

model = MusicGen.get_pretrained('melody')
model.set_generation_params(duration=8)  # generate 8 seconds.
# wav = model.generate_unconditional(4)    # generates 4 unconditional audio samples
# descriptions = ['happy rock', 'energetic EDM', 'sad jazz']
# wav = model.generate(descriptions)  # generates 3 samples.

# melody, sr = torchaudio.load('./assets/bach.mp3')
# # generates using the melody from the given audio and the provided descriptions.
# wav = model.generate_with_chroma(descriptions, melody[None].expand(3, -1, -1), sr)

for idx, one_wav in enumerate(wav):
    # Will save under {idx}.wav, with loudness normalization at -14 db LUFS.
    audio_write(f'{idx}', one_wav.cpu(), model.sample_rate, strategy="loudness", loudness_compressor=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#       2 from audiocraft.models import MusicGen
#       3 from audiocraft.data.audio import audio_write
# ----> 5 model = MusicGen.get_pretrained('melody')
#       6 model.set_generation_params(duration=8)  # generate 8 seconds.
#       7 # wav = model.generate_unconditional(4)    # generates 4 unconditional audio samples
#       8 # descriptions = ['happy rock', 'energetic EDM', 'sad jazz']
#       9 # wav = model.generate(descriptions)  # generates 3 samples.
#    (...)
#      12 # # generates using the melody from the given audio and the provided descriptions.
#      13 # wav = model.generate_with_chroma(descriptions, melody[None].expand(3, -1, -1), sr)
#
# File D:\anaconda3\lib\site-packages\audiocraft\models\musicgen.py:88, in MusicGen.get_pretrained(name, device)
#      86 else:
#      87     ROOT = 'https://dl.fbaipublicfiles.com/audiocraft/musicgen/v0/'
# ---> 88 compression_model = load_compression_model(ROOT + 'b0dbef54-37d256b525.th', device=device)
#      89 names = {
#      90     'small': 'ba7a97ba-830fe5771e',
#      91     'medium': 'aa73ae27-fbc9f401db',
#      92     'large': '9b6e835c-1f0cf17b5e',
#      93     'melody': 'f79af192-61305ffc49',
#      94 }
#      95 sig = names[name]
#
# File D:\anaconda3\lib\site-packages\audiocraft\models\loaders.py:45, in load_compression_model(file_or_url, device)
#      43 cfg = OmegaConf.create(pkg['xp.cfg'])
#      44 cfg.device = str(device)
# ---> 45 model = builders.get_compression_model(cfg)
#      46 model.load_state_dict(pkg['best_state'])
#      47 model.eval()
#
# File D:\anaconda3\lib\site-packages\audiocraft\models\builders.py:81, in get_compression_model(cfg)
#      79         renormalize = renorm is not None
#      80         warnings.warn("You are using a deprecated EnCodec model. Please migrate to new renormalization.")
# ---> 81     return EncodecModel(encoder, decoder, quantizer,
#      82                         frame_rate=frame_rate, renormalize=renormalize, **kwargs).to(cfg.device)
#      83 else:
#      84     raise KeyError(f'Unexpected compression model {cfg.compression_model}')
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 797 (2 times)]
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File D:\anaconda3\lib\site-packages\torch\nn\modules\module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File D:\anaconda3\lib\site-packages\torch\cuda\__init__.py:239, in _lazy_init()
#     235     raise RuntimeError(
#     236         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     237         "multiprocessing, you must use the 'spawn' start method")
#     238 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 239     raise AssertionError("Torch not compiled with CUDA enabled")
#     240 if _cudart is None:
#     241     raise AssertionError(
#     242         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled
